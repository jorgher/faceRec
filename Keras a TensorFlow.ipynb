# %%
from keras.models import model_from_json
from keras import backend as K
import tensorflow as tf
# Out:
# /home/jorgel/.virtualenvs/dl4cv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model_file = "EmoClassModel.json"
weights_file = "EmoClassWeights.h5"

# %%
with open(model_file, "r") as file:
    config = file.read()

# %%
K.set_learning_phase(0)
model = model_from_json(config)
model.load_weights(weights_file)

# %%
saver = tf.train.Saver()
sess = K.get_session()
saver.save(sess, "./TF_Model/tf_model")
sess.graph.get_operations()
# Out:
# [<tf.Operation 'conv2d_1_input' type=Placeholder>,
#  <tf.Operation 'conv2d_1/random_uniform/shape' type=Const>,
#  <tf.Operation 'conv2d_1/random_uniform/min' type=Const>,
#  <tf.Operation 'conv2d_1/random_uniform/max' type=Const>,
#  <tf.Operation 'conv2d_1/random_uniform/RandomUniform' type=RandomUniform>,
#  <tf.Operation 'conv2d_1/random_uniform/sub' type=Sub>,
#  <tf.Operation 'conv2d_1/random_uniform/mul' type=Mul>,
#  <tf.Operation 'conv2d_1/random_uniform' type=Add>,
#  <tf.Operation 'conv2d_1/kernel' type=VariableV2>,
#  <tf.Operation 'conv2d_1/kernel/Assign' type=Assign>,
#  <tf.Operation 'conv2d_1/kernel/read' type=Identity>,
#  <tf.Operation 'conv2d_1/Const' type=Const>,
#  <tf.Operation 'conv2d_1/bias' type=VariableV2>,
#  <tf.Operation 'conv2d_1/bias/Assign' type=Assign>,
#  <tf.Operation 'conv2d_1/bias/read' type=Identity>,
#  <tf.Operation 'conv2d_1/convolution/dilation_rate' type=Const>,
#  <tf.Operation 'conv2d_1/convolution' type=Conv2D>,
#  <tf.Operation 'conv2d_1/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_1/Relu' type=Relu>,
#  <tf.Operation 'batch_normalization_1/Const' type=Const>,
#  <tf.Operation 'batch_normalization_1/gamma' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/gamma/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/Const_1' type=Const>,
#  <tf.Operation 'batch_normalization_1/beta' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/beta/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/Const_2' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_mean' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/moving_mean/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/Const_3' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_variance' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/moving_variance/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/IsVariableInitialized' type=IsVariableInitialized>,
#  <tf.Operation 'batch_normalization_1/IsVariableInitialized_1' type=IsVariableInitialized>,
#  <tf.Operation 'batch_normalization_1/IsVariableInitialized_2' type=IsVariableInitialized>,
#  <tf.Operation 'batch_normalization_1/IsVariableInitialized_3' type=IsVariableInitialized>,
#  <tf.Operation 'batch_normalization_1/IsVariableInitialized_4' type=IsVariableInitialized>,
#  <tf.Operation 'batch_normalization_1/IsVariableInitialized_5' type=IsVariableInitialized>,
#  <tf.Operation 'batch_normalization_1/init' type=NoOp>,
#  <tf.Operation 'batch_normalization_1/Const_4' type=Const>,
#  <tf.Operation 'batch_normalization_1/Const_5' type=Const>,
#  <tf.Operation 'batch_normalization_1/FusedBatchNorm' type=FusedBatchNorm>,
#  <tf.Operation 'batch_normalization_1/Shape' type=Shape>,
#  <tf.Operation 'batch_normalization_1/strided_slice/stack' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_1/Shape_1' type=Shape>,
#  <tf.Operation 'batch_normalization_1/strided_slice_1/stack' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice_1/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice_1/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice_1' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_1/Shape_2' type=Shape>,
#  <tf.Operation 'batch_normalization_1/strided_slice_2/stack' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice_2/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice_2/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_1/strided_slice_2' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_1/Rank/packed' type=Pack>,
#  <tf.Operation 'batch_normalization_1/Rank' type=Const>,
#  <tf.Operation 'batch_normalization_1/range/start' type=Const>,
#  <tf.Operation 'batch_normalization_1/range/delta' type=Const>,
#  <tf.Operation 'batch_normalization_1/range' type=Range>,
#  <tf.Operation 'batch_normalization_1/Prod/input' type=Pack>,
#  <tf.Operation 'batch_normalization_1/Prod' type=Prod>,
#  <tf.Operation 'batch_normalization_1/Cast' type=Cast>,
#  <tf.Operation 'batch_normalization_1/sub/y' type=Const>,
#  <tf.Operation 'batch_normalization_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_1/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/decay' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_1/moving_mean/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/moving_mean/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/moving_mean/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/moving_mean/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_mean/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_mean/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_1/moving_mean/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/moving_mean/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/moving_mean/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/batch_normalization_1/moving_mean' type=AssignSub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg/batch_normalization_1/moving_mean/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg' type=AssignSub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/decay' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_1/moving_variance/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/moving_variance/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/moving_variance/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/moving_variance/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_variance/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_variance/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_1/moving_variance/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_1/moving_variance/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_1/moving_variance/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/batch_normalization_1/moving_variance' type=AssignSub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1/batch_normalization_1/moving_variance/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_1/AssignMovingAvg_1' type=AssignSub>,
#  <tf.Operation 'batch_normalization_1/batchnorm/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_1/batchnorm/add' type=Add>,
#  <tf.Operation 'batch_normalization_1/batchnorm/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_1/batchnorm/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_1/batchnorm/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_1/batchnorm/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_1/batchnorm/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_1/batchnorm/add_1' type=Add>,
#  <tf.Operation 'max_pooling2d_1/MaxPool' type=MaxPool>,
#  <tf.Operation 'dropout_1/Identity' type=Identity>,
#  <tf.Operation 'conv2d_2/random_uniform/shape' type=Const>,
#  <tf.Operation 'conv2d_2/random_uniform/min' type=Const>,
#  <tf.Operation 'conv2d_2/random_uniform/max' type=Const>,
#  <tf.Operation 'conv2d_2/random_uniform/RandomUniform' type=RandomUniform>,
#  <tf.Operation 'conv2d_2/random_uniform/sub' type=Sub>,
#  <tf.Operation 'conv2d_2/random_uniform/mul' type=Mul>,
#  <tf.Operation 'conv2d_2/random_uniform' type=Add>,
#  <tf.Operation 'conv2d_2/kernel' type=VariableV2>,
#  <tf.Operation 'conv2d_2/kernel/Assign' type=Assign>,
#  <tf.Operation 'conv2d_2/kernel/read' type=Identity>,
#  <tf.Operation 'conv2d_2/Const' type=Const>,
#  <tf.Operation 'conv2d_2/bias' type=VariableV2>,
#  <tf.Operation 'conv2d_2/bias/Assign' type=Assign>,
#  <tf.Operation 'conv2d_2/bias/read' type=Identity>,
#  <tf.Operation 'conv2d_2/convolution/dilation_rate' type=Const>,
#  <tf.Operation 'conv2d_2/convolution' type=Conv2D>,
#  <tf.Operation 'conv2d_2/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_2/Relu' type=Relu>,
#  <tf.Operation 'batch_normalization_2/Const' type=Const>,
#  <tf.Operation 'batch_normalization_2/gamma' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/gamma/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/Const_1' type=Const>,
#  <tf.Operation 'batch_normalization_2/beta' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/beta/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/Const_2' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_mean' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/moving_mean/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/Const_3' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_variance' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/moving_variance/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/Const_4' type=Const>,
#  <tf.Operation 'batch_normalization_2/Const_5' type=Const>,
#  <tf.Operation 'batch_normalization_2/FusedBatchNorm' type=FusedBatchNorm>,
#  <tf.Operation 'batch_normalization_2/Shape' type=Shape>,
#  <tf.Operation 'batch_normalization_2/strided_slice/stack' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_2/Shape_1' type=Shape>,
#  <tf.Operation 'batch_normalization_2/strided_slice_1/stack' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice_1/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice_1/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice_1' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_2/Shape_2' type=Shape>,
#  <tf.Operation 'batch_normalization_2/strided_slice_2/stack' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice_2/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice_2/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_2/strided_slice_2' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_2/Rank/packed' type=Pack>,
#  <tf.Operation 'batch_normalization_2/Rank' type=Const>,
#  <tf.Operation 'batch_normalization_2/range/start' type=Const>,
#  <tf.Operation 'batch_normalization_2/range/delta' type=Const>,
#  <tf.Operation 'batch_normalization_2/range' type=Range>,
#  <tf.Operation 'batch_normalization_2/Prod/input' type=Pack>,
#  <tf.Operation 'batch_normalization_2/Prod' type=Prod>,
#  <tf.Operation 'batch_normalization_2/Cast' type=Cast>,
#  <tf.Operation 'batch_normalization_2/sub/y' type=Const>,
#  <tf.Operation 'batch_normalization_2/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_2/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_2/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/decay' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_2/moving_mean/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/moving_mean/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/moving_mean/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/moving_mean/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_mean/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_mean/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_2/moving_mean/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/moving_mean/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/moving_mean/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/batch_normalization_2/moving_mean' type=AssignSub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg/batch_normalization_2/moving_mean/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg' type=AssignSub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/decay' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_2/moving_variance/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/moving_variance/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/moving_variance/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/moving_variance/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_variance/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_variance/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_2/moving_variance/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_2/moving_variance/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_2/moving_variance/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/batch_normalization_2/moving_variance' type=AssignSub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1/batch_normalization_2/moving_variance/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_2/AssignMovingAvg_1' type=AssignSub>,
#  <tf.Operation 'batch_normalization_2/batchnorm/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_2/batchnorm/add' type=Add>,
#  <tf.Operation 'batch_normalization_2/batchnorm/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_2/batchnorm/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_2/batchnorm/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_2/batchnorm/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_2/batchnorm/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_2/batchnorm/add_1' type=Add>,
#  <tf.Operation 'conv2d_3/random_uniform/shape' type=Const>,
#  <tf.Operation 'conv2d_3/random_uniform/min' type=Const>,
#  <tf.Operation 'conv2d_3/random_uniform/max' type=Const>,
#  <tf.Operation 'conv2d_3/random_uniform/RandomUniform' type=RandomUniform>,
#  <tf.Operation 'conv2d_3/random_uniform/sub' type=Sub>,
#  <tf.Operation 'conv2d_3/random_uniform/mul' type=Mul>,
#  <tf.Operation 'conv2d_3/random_uniform' type=Add>,
#  <tf.Operation 'conv2d_3/kernel' type=VariableV2>,
#  <tf.Operation 'conv2d_3/kernel/Assign' type=Assign>,
#  <tf.Operation 'conv2d_3/kernel/read' type=Identity>,
#  <tf.Operation 'conv2d_3/Const' type=Const>,
#  <tf.Operation 'conv2d_3/bias' type=VariableV2>,
#  <tf.Operation 'conv2d_3/bias/Assign' type=Assign>,
#  <tf.Operation 'conv2d_3/bias/read' type=Identity>,
#  <tf.Operation 'conv2d_3/convolution/dilation_rate' type=Const>,
#  <tf.Operation 'conv2d_3/convolution' type=Conv2D>,
#  <tf.Operation 'conv2d_3/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_3/Relu' type=Relu>,
#  <tf.Operation 'batch_normalization_3/Const' type=Const>,
#  <tf.Operation 'batch_normalization_3/gamma' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/gamma/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/Const_1' type=Const>,
#  <tf.Operation 'batch_normalization_3/beta' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/beta/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/Const_2' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_mean' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/moving_mean/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/Const_3' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_variance' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/moving_variance/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/Const_4' type=Const>,
#  <tf.Operation 'batch_normalization_3/Const_5' type=Const>,
#  <tf.Operation 'batch_normalization_3/FusedBatchNorm' type=FusedBatchNorm>,
#  <tf.Operation 'batch_normalization_3/Shape' type=Shape>,
#  <tf.Operation 'batch_normalization_3/strided_slice/stack' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_3/Shape_1' type=Shape>,
#  <tf.Operation 'batch_normalization_3/strided_slice_1/stack' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice_1/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice_1/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice_1' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_3/Shape_2' type=Shape>,
#  <tf.Operation 'batch_normalization_3/strided_slice_2/stack' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice_2/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice_2/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_3/strided_slice_2' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_3/Rank/packed' type=Pack>,
#  <tf.Operation 'batch_normalization_3/Rank' type=Const>,
#  <tf.Operation 'batch_normalization_3/range/start' type=Const>,
#  <tf.Operation 'batch_normalization_3/range/delta' type=Const>,
#  <tf.Operation 'batch_normalization_3/range' type=Range>,
#  <tf.Operation 'batch_normalization_3/Prod/input' type=Pack>,
#  <tf.Operation 'batch_normalization_3/Prod' type=Prod>,
#  <tf.Operation 'batch_normalization_3/Cast' type=Cast>,
#  <tf.Operation 'batch_normalization_3/sub/y' type=Const>,
#  <tf.Operation 'batch_normalization_3/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_3/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_3/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/decay' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_3/moving_mean/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/moving_mean/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/moving_mean/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/moving_mean/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_mean/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_mean/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_3/moving_mean/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/moving_mean/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/moving_mean/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/batch_normalization_3/moving_mean' type=AssignSub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg/batch_normalization_3/moving_mean/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg' type=AssignSub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/decay' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_3/moving_variance/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/moving_variance/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/moving_variance/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/moving_variance/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_variance/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_variance/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_3/moving_variance/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_3/moving_variance/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_3/moving_variance/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/batch_normalization_3/moving_variance' type=AssignSub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1/batch_normalization_3/moving_variance/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_3/AssignMovingAvg_1' type=AssignSub>,
#  <tf.Operation 'batch_normalization_3/batchnorm/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_3/batchnorm/add' type=Add>,
#  <tf.Operation 'batch_normalization_3/batchnorm/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_3/batchnorm/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_3/batchnorm/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_3/batchnorm/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_3/batchnorm/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_3/batchnorm/add_1' type=Add>,
#  <tf.Operation 'max_pooling2d_2/MaxPool' type=MaxPool>,
#  <tf.Operation 'dropout_2/Identity' type=Identity>,
#  <tf.Operation 'conv2d_4/random_uniform/shape' type=Const>,
#  <tf.Operation 'conv2d_4/random_uniform/min' type=Const>,
#  <tf.Operation 'conv2d_4/random_uniform/max' type=Const>,
#  <tf.Operation 'conv2d_4/random_uniform/RandomUniform' type=RandomUniform>,
#  <tf.Operation 'conv2d_4/random_uniform/sub' type=Sub>,
#  <tf.Operation 'conv2d_4/random_uniform/mul' type=Mul>,
#  <tf.Operation 'conv2d_4/random_uniform' type=Add>,
#  <tf.Operation 'conv2d_4/kernel' type=VariableV2>,
#  <tf.Operation 'conv2d_4/kernel/Assign' type=Assign>,
#  <tf.Operation 'conv2d_4/kernel/read' type=Identity>,
#  <tf.Operation 'conv2d_4/Const' type=Const>,
#  <tf.Operation 'conv2d_4/bias' type=VariableV2>,
#  <tf.Operation 'conv2d_4/bias/Assign' type=Assign>,
#  <tf.Operation 'conv2d_4/bias/read' type=Identity>,
#  <tf.Operation 'conv2d_4/convolution/dilation_rate' type=Const>,
#  <tf.Operation 'conv2d_4/convolution' type=Conv2D>,
#  <tf.Operation 'conv2d_4/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_4/Relu' type=Relu>,
#  <tf.Operation 'batch_normalization_4/Const' type=Const>,
#  <tf.Operation 'batch_normalization_4/gamma' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/gamma/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/Const_1' type=Const>,
#  <tf.Operation 'batch_normalization_4/beta' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/beta/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/Const_2' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_mean' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/moving_mean/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/Const_3' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_variance' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/moving_variance/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/Const_4' type=Const>,
#  <tf.Operation 'batch_normalization_4/Const_5' type=Const>,
#  <tf.Operation 'batch_normalization_4/FusedBatchNorm' type=FusedBatchNorm>,
#  <tf.Operation 'batch_normalization_4/Shape' type=Shape>,
#  <tf.Operation 'batch_normalization_4/strided_slice/stack' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_4/Shape_1' type=Shape>,
#  <tf.Operation 'batch_normalization_4/strided_slice_1/stack' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice_1/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice_1/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice_1' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_4/Shape_2' type=Shape>,
#  <tf.Operation 'batch_normalization_4/strided_slice_2/stack' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice_2/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice_2/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_4/strided_slice_2' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_4/Rank/packed' type=Pack>,
#  <tf.Operation 'batch_normalization_4/Rank' type=Const>,
#  <tf.Operation 'batch_normalization_4/range/start' type=Const>,
#  <tf.Operation 'batch_normalization_4/range/delta' type=Const>,
#  <tf.Operation 'batch_normalization_4/range' type=Range>,
#  <tf.Operation 'batch_normalization_4/Prod/input' type=Pack>,
#  <tf.Operation 'batch_normalization_4/Prod' type=Prod>,
#  <tf.Operation 'batch_normalization_4/Cast' type=Cast>,
#  <tf.Operation 'batch_normalization_4/sub/y' type=Const>,
#  <tf.Operation 'batch_normalization_4/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_4/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_4/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/decay' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_4/moving_mean/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/moving_mean/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/moving_mean/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/moving_mean/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_mean/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_mean/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_4/moving_mean/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/moving_mean/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/moving_mean/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/batch_normalization_4/moving_mean' type=AssignSub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg/batch_normalization_4/moving_mean/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg' type=AssignSub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/decay' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_4/moving_variance/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/moving_variance/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/moving_variance/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/moving_variance/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_variance/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_variance/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_4/moving_variance/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_4/moving_variance/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_4/moving_variance/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/batch_normalization_4/moving_variance' type=AssignSub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1/batch_normalization_4/moving_variance/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_4/AssignMovingAvg_1' type=AssignSub>,
#  <tf.Operation 'batch_normalization_4/batchnorm/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_4/batchnorm/add' type=Add>,
#  <tf.Operation 'batch_normalization_4/batchnorm/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_4/batchnorm/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_4/batchnorm/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_4/batchnorm/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_4/batchnorm/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_4/batchnorm/add_1' type=Add>,
#  <tf.Operation 'conv2d_5/random_uniform/shape' type=Const>,
#  <tf.Operation 'conv2d_5/random_uniform/min' type=Const>,
#  <tf.Operation 'conv2d_5/random_uniform/max' type=Const>,
#  <tf.Operation 'conv2d_5/random_uniform/RandomUniform' type=RandomUniform>,
#  <tf.Operation 'conv2d_5/random_uniform/sub' type=Sub>,
#  <tf.Operation 'conv2d_5/random_uniform/mul' type=Mul>,
#  <tf.Operation 'conv2d_5/random_uniform' type=Add>,
#  <tf.Operation 'conv2d_5/kernel' type=VariableV2>,
#  <tf.Operation 'conv2d_5/kernel/Assign' type=Assign>,
#  <tf.Operation 'conv2d_5/kernel/read' type=Identity>,
#  <tf.Operation 'conv2d_5/Const' type=Const>,
#  <tf.Operation 'conv2d_5/bias' type=VariableV2>,
#  <tf.Operation 'conv2d_5/bias/Assign' type=Assign>,
#  <tf.Operation 'conv2d_5/bias/read' type=Identity>,
#  <tf.Operation 'conv2d_5/convolution/dilation_rate' type=Const>,
#  <tf.Operation 'conv2d_5/convolution' type=Conv2D>,
#  <tf.Operation 'conv2d_5/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_5/Relu' type=Relu>,
#  <tf.Operation 'batch_normalization_5/Const' type=Const>,
#  <tf.Operation 'batch_normalization_5/gamma' type=VariableV2>,
#  <tf.Operation 'batch_normalization_5/gamma/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_5/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/Const_1' type=Const>,
#  <tf.Operation 'batch_normalization_5/beta' type=VariableV2>,
#  <tf.Operation 'batch_normalization_5/beta/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_5/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/Const_2' type=Const>,
#  <tf.Operation 'batch_normalization_5/moving_mean' type=VariableV2>,
#  <tf.Operation 'batch_normalization_5/moving_mean/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_5/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/Const_3' type=Const>,
#  <tf.Operation 'batch_normalization_5/moving_variance' type=VariableV2>,
#  <tf.Operation 'batch_normalization_5/moving_variance/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_5/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/Const_4' type=Const>,
#  <tf.Operation 'batch_normalization_5/Const_5' type=Const>,
#  <tf.Operation 'batch_normalization_5/FusedBatchNorm' type=FusedBatchNorm>,
#  <tf.Operation 'batch_normalization_5/Shape' type=Shape>,
#  <tf.Operation 'batch_normalization_5/strided_slice/stack' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_5/Shape_1' type=Shape>,
#  <tf.Operation 'batch_normalization_5/strided_slice_1/stack' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice_1/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice_1/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice_1' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_5/Shape_2' type=Shape>,
#  <tf.Operation 'batch_normalization_5/strided_slice_2/stack' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice_2/stack_1' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice_2/stack_2' type=Const>,
#  <tf.Operation 'batch_normalization_5/strided_slice_2' type=StridedSlice>,
#  <tf.Operation 'batch_normalization_5/Rank/packed' type=Pack>,
#  <tf.Operation 'batch_normalization_5/Rank' type=Const>,
#  <tf.Operation 'batch_normalization_5/range/start' type=Const>,
#  <tf.Operation 'batch_normalization_5/range/delta' type=Const>,
#  <tf.Operation 'batch_normalization_5/range' type=Range>,
#  <tf.Operation 'batch_normalization_5/Prod/input' type=Pack>,
#  <tf.Operation 'batch_normalization_5/Prod' type=Prod>,
#  <tf.Operation 'batch_normalization_5/Cast' type=Cast>,
#  <tf.Operation 'batch_normalization_5/sub/y' type=Const>,
#  <tf.Operation 'batch_normalization_5/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_5/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_5/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/decay' type=Const>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_5/moving_mean/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_5/moving_mean/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_5/moving_mean/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/moving_mean/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_5/moving_mean/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_5/moving_mean/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_5/moving_mean/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_5/moving_mean/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_5/moving_mean/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/batch_normalization_5/moving_mean' type=AssignSub>,
#  <tf.Operation 'batch_normalization_5/AssignMovingAvg/batch_normalization_5/moving_mean/AssignAdd/value' type=Const>,
# ...
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/batch_normalization_6/moving_mean' type=AssignSub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg/batch_normalization_6/moving_mean/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg' type=AssignSub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/decay' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_6/moving_variance/biased' type=VariableV2>,
#  <tf.Operation 'batch_normalization_6/moving_variance/biased/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_6/moving_variance/biased/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/moving_variance/local_step/Initializer/zeros/shape_as_tensor' type=Const>,
#  <tf.Operation 'batch_normalization_6/moving_variance/local_step/Initializer/zeros/Const' type=Const>,
#  <tf.Operation 'batch_normalization_6/moving_variance/local_step/Initializer/zeros' type=Fill>,
#  <tf.Operation 'batch_normalization_6/moving_variance/local_step' type=VariableV2>,
#  <tf.Operation 'batch_normalization_6/moving_variance/local_step/Assign' type=Assign>,
#  <tf.Operation 'batch_normalization_6/moving_variance/local_step/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/batch_normalization_6/moving_variance' type=AssignSub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/AssignAdd/value' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/AssignAdd' type=AssignAdd>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/sub_1/x' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/sub_1' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/read_1' type=Identity>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/Pow' type=Pow>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/sub_2/x' type=Const>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/sub_2' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/truediv' type=RealDiv>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1/batch_normalization_6/moving_variance/sub_3' type=Sub>,
#  <tf.Operation 'batch_normalization_6/AssignMovingAvg_1' type=AssignSub>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'dropout_4/Identity' type=Identity>,
#  <tf.Operation 'dense_2/random_uniform/shape' type=Const>,
#  <tf.Operation 'dense_2/random_uniform/min' type=Const>,
#  <tf.Operation 'dense_2/random_uniform/max' type=Const>,
#  <tf.Operation 'dense_2/random_uniform/RandomUniform' type=RandomUniform>,
#  <tf.Operation 'dense_2/random_uniform/sub' type=Sub>,
#  <tf.Operation 'dense_2/random_uniform/mul' type=Mul>,
#  <tf.Operation 'dense_2/random_uniform' type=Add>,
#  <tf.Operation 'dense_2/kernel' type=VariableV2>,
#  <tf.Operation 'dense_2/kernel/Assign' type=Assign>,
#  <tf.Operation 'dense_2/kernel/read' type=Identity>,
#  <tf.Operation 'dense_2/Const' type=Const>,
#  <tf.Operation 'dense_2/bias' type=VariableV2>,
#  <tf.Operation 'dense_2/bias/Assign' type=Assign>,
#  <tf.Operation 'dense_2/bias/read' type=Identity>,
#  <tf.Operation 'dense_2/MatMul' type=MatMul>,
#  <tf.Operation 'dense_2/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_7/Softmax' type=Softmax>,
#  <tf.Operation 'Placeholder' type=Placeholder>,
#  <tf.Operation 'Assign' type=Assign>,
#  <tf.Operation 'Placeholder_1' type=Placeholder>,
#  <tf.Operation 'Assign_1' type=Assign>,
#  <tf.Operation 'Placeholder_2' type=Placeholder>,
#  <tf.Operation 'Assign_2' type=Assign>,
#  <tf.Operation 'Placeholder_3' type=Placeholder>,
#  <tf.Operation 'Assign_3' type=Assign>,
#  <tf.Operation 'Placeholder_4' type=Placeholder>,
#  <tf.Operation 'Assign_4' type=Assign>,
#  <tf.Operation 'Placeholder_5' type=Placeholder>,
#  <tf.Operation 'Assign_5' type=Assign>,
#  <tf.Operation 'Placeholder_6' type=Placeholder>,
#  <tf.Operation 'Assign_6' type=Assign>,
#  <tf.Operation 'Placeholder_7' type=Placeholder>,
#  <tf.Operation 'Assign_7' type=Assign>,
#  <tf.Operation 'Placeholder_8' type=Placeholder>,
#  <tf.Operation 'Assign_8' type=Assign>,
#  <tf.Operation 'Placeholder_9' type=Placeholder>,
#  <tf.Operation 'Assign_9' type=Assign>,
#  <tf.Operation 'Placeholder_10' type=Placeholder>,
#  <tf.Operation 'Assign_10' type=Assign>,
#  <tf.Operation 'Placeholder_11' type=Placeholder>,
#  <tf.Operation 'Assign_11' type=Assign>,
#  <tf.Operation 'Placeholder_12' type=Placeholder>,
#  <tf.Operation 'Assign_12' type=Assign>,
#  <tf.Operation 'Placeholder_13' type=Placeholder>,
#  <tf.Operation 'Assign_13' type=Assign>,
#  <tf.Operation 'Placeholder_14' type=Placeholder>,
#  <tf.Operation 'Assign_14' type=Assign>,
#  <tf.Operation 'Placeholder_15' type=Placeholder>,
#  <tf.Operation 'Assign_15' type=Assign>,
#  <tf.Operation 'Placeholder_16' type=Placeholder>,
#  <tf.Operation 'Assign_16' type=Assign>,
#  <tf.Operation 'Placeholder_17' type=Placeholder>,
#  <tf.Operation 'Assign_17' type=Assign>,
#  <tf.Operation 'Placeholder_18' type=Placeholder>,
#  <tf.Operation 'Assign_18' type=Assign>,
#  <tf.Operation 'Placeholder_19' type=Placeholder>,
#  <tf.Operation 'Assign_19' type=Assign>,
#  <tf.Operation 'Placeholder_20' type=Placeholder>,
#  <tf.Operation 'Assign_20' type=Assign>,
#  <tf.Operation 'Placeholder_21' type=Placeholder>,
#  <tf.Operation 'Assign_21' type=Assign>,
#  <tf.Operation 'Placeholder_22' type=Placeholder>,
#  <tf.Operation 'Assign_22' type=Assign>,
#  <tf.Operation 'Placeholder_23' type=Placeholder>,
#  <tf.Operation 'Assign_23' type=Assign>,
#  <tf.Operation 'Placeholder_24' type=Placeholder>,
#  <tf.Operation 'Assign_24' type=Assign>,
#  <tf.Operation 'Placeholder_25' type=Placeholder>,
#  <tf.Operation 'Assign_25' type=Assign>,
#  <tf.Operation 'Placeholder_26' type=Placeholder>,
#  <tf.Operation 'Assign_26' type=Assign>,
#  <tf.Operation 'Placeholder_27' type=Placeholder>,
#  <tf.Operation 'Assign_27' type=Assign>,
#  <tf.Operation 'Placeholder_28' type=Placeholder>,
#  <tf.Operation 'Assign_28' type=Assign>,
#  <tf.Operation 'Placeholder_29' type=Placeholder>,
#  <tf.Operation 'Assign_29' type=Assign>,
#  <tf.Operation 'Placeholder_30' type=Placeholder>,
#  <tf.Operation 'Assign_30' type=Assign>,
#  <tf.Operation 'Placeholder_31' type=Placeholder>,
#  <tf.Operation 'Assign_31' type=Assign>,
#  <tf.Operation 'Placeholder_32' type=Placeholder>,
#  <tf.Operation 'Assign_32' type=Assign>,
#  <tf.Operation 'Placeholder_33' type=Placeholder>,
#  <tf.Operation 'Assign_33' type=Assign>,
#  <tf.Operation 'Placeholder_34' type=Placeholder>,
#  <tf.Operation 'Assign_34' type=Assign>,
#  <tf.Operation 'Placeholder_35' type=Placeholder>,
#  <tf.Operation 'Assign_35' type=Assign>,
#  <tf.Operation 'Placeholder_36' type=Placeholder>,
#  <tf.Operation 'Assign_36' type=Assign>,
#  <tf.Operation 'Placeholder_37' type=Placeholder>,
#  <tf.Operation 'Assign_37' type=Assign>,
#  <tf.Operation 'IsVariableInitialized' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_1' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_2' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_3' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_4' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_5' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_6' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_7' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_8' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_9' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_10' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_11' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_12' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_13' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_14' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_15' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_16' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_17' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_18' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_19' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_20' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_21' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_22' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_23' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_24' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_25' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_26' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_27' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_28' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_29' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_30' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_31' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_32' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_33' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_34' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_35' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_36' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_37' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_38' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_39' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_40' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_41' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_42' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_43' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_44' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_45' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_46' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_47' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_48' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_49' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_50' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_51' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_52' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_53' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_54' type=IsVariableInitialized>,
#  <tf.Operation 'IsVariableInitialized_55' type=IsVariableInitialized>,
#  <tf.Operation 'init' type=NoOp>,
#  <tf.Operation 'save/Const' type=Const>,
#  <tf.Operation 'save/SaveV2/tensor_names' type=Const>,
#  <tf.Operation 'save/SaveV2/shape_and_slices' type=Const>,
#  <tf.Operation 'save/SaveV2' type=SaveV2>,
#  <tf.Operation 'save/control_dependency' type=Identity>,
#  <tf.Operation 'save/RestoreV2/tensor_names' type=Const>,
#  <tf.Operation 'save/RestoreV2/shape_and_slices' type=Const>,
#  <tf.Operation 'save/RestoreV2' type=RestoreV2>,
#  <tf.Operation 'save/Assign' type=Assign>,
#  <tf.Operation 'save/Assign_1' type=Assign>,
#  <tf.Operation 'save/Assign_2' type=Assign>,
#  <tf.Operation 'save/Assign_3' type=Assign>,
#  <tf.Operation 'save/Assign_4' type=Assign>,
#  <tf.Operation 'save/Assign_5' type=Assign>,
#  <tf.Operation 'save/Assign_6' type=Assign>,
#  <tf.Operation 'save/Assign_7' type=Assign>,
#  <tf.Operation 'save/Assign_8' type=Assign>,
#  <tf.Operation 'save/Assign_9' type=Assign>,
#  <tf.Operation 'save/Assign_10' type=Assign>,
#  <tf.Operation 'save/Assign_11' type=Assign>,
#  <tf.Operation 'save/Assign_12' type=Assign>,
#  <tf.Operation 'save/Assign_13' type=Assign>,
#  <tf.Operation 'save/Assign_14' type=Assign>,
#  <tf.Operation 'save/Assign_15' type=Assign>,
#  <tf.Operation 'save/Assign_16' type=Assign>,
#  <tf.Operation 'save/Assign_17' type=Assign>,
#  <tf.Operation 'save/Assign_18' type=Assign>,
#  <tf.Operation 'save/Assign_19' type=Assign>,
#  <tf.Operation 'save/Assign_20' type=Assign>,
#  <tf.Operation 'save/Assign_21' type=Assign>,
#  <tf.Operation 'save/Assign_22' type=Assign>,
#  <tf.Operation 'save/Assign_23' type=Assign>,
#  <tf.Operation 'save/Assign_24' type=Assign>,
#  <tf.Operation 'save/Assign_25' type=Assign>,
#  <tf.Operation 'save/Assign_26' type=Assign>,
#  <tf.Operation 'save/Assign_27' type=Assign>,
#  <tf.Operation 'save/Assign_28' type=Assign>,
#  <tf.Operation 'save/Assign_29' type=Assign>,
#  <tf.Operation 'save/Assign_30' type=Assign>,
#  <tf.Operation 'save/Assign_31' type=Assign>,
#  <tf.Operation 'save/Assign_32' type=Assign>,
#  <tf.Operation 'save/Assign_33' type=Assign>,
#  <tf.Operation 'save/Assign_34' type=Assign>,
#  <tf.Operation 'save/Assign_35' type=Assign>,
#  <tf.Operation 'save/Assign_36' type=Assign>,
#  <tf.Operation 'save/Assign_37' type=Assign>,
#  <tf.Operation 'save/Assign_38' type=Assign>,
#  <tf.Operation 'save/Assign_39' type=Assign>,
#  <tf.Operation 'save/Assign_40' type=Assign>,
#  <tf.Operation 'save/Assign_41' type=Assign>,
#  <tf.Operation 'save/Assign_42' type=Assign>,
#  <tf.Operation 'save/Assign_43' type=Assign>,
#  <tf.Operation 'save/Assign_44' type=Assign>,
#  <tf.Operation 'save/Assign_45' type=Assign>,
#  <tf.Operation 'save/Assign_46' type=Assign>,
#  ...]

# %%
fw = tf.summary.FileWriter('logs', sess.graph)
fw.close()

# %%
mvNCCompile TF_Model/tf_model.meta -in=conv2d_1_input -on=dense_2/Softmax
# Out:
#   File "<ipython-input-7-28c244c83ea6>", line 1
#     mvNCCompile TF_Model/tf_model.meta -in=conv2d_1_input -on=dense_2/Softmax
#                        ^
# SyntaxError: invalid syntax

# %%
mvNCCompile
# Out:
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# <ipython-input-8-76fa0754f3f0> in <module>()
# ----> 1 mvNCCompile
#
# NameError: name 'mvNCCompile' is not defined
