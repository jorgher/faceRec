# %%
import pandas as pd
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
 
dataset_path = 'fer2013/fer2013.csv'
image_size=(48,48)
 
def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).as_matrix()
    return faces, emotions
 
def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)

#print("Size {}".format(len(labels)))
#print(labels.shape)
print(xtrain.shape, xtest.shape)
print(ytrain.shape, ytest.shape)
# Out:
# /home/jogel/caffe_gpu/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# (28709, 48, 48, 1) (7178, 48, 48, 1)
# (28709, 7) (7178, 7)

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2
import pandas as pd
import cv2
import numpy as np
 
# parameters
batch_size = 32
num_epochs = 110
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = '/home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/'
l2_regularization=0.01
 
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l2(l2_regularization)
 
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
 
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
 
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_acc:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 46, 46, 8)    72          input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 46, 46, 8)    32          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 46, 46, 8)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 44, 44, 8)    576         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 44, 44, 8)    32          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 44, 44, 8)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 44, 44, 16)   200         activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 44, 44, 16)   64          separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 44, 44, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 44, 44, 16)   400         activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 44, 44, 16)   64          separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 22, 22, 16)   128         activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 22, 22, 16)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 22, 22, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 22, 22, 16)   0           max_pooling2d_5[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 22, 22, 32)   656         add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 22, 22, 32)   128         separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 22, 22, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 22, 22, 32)   1312        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 22, 22, 32)   128         separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 11, 11, 32)   512         add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 11, 11, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 11, 11, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 11, 11, 32)   0           max_pooling2d_6[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 11, 11, 64)   2336        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 11, 11, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 11, 11, 64)   4672        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 6, 6, 64)     2048        add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 64)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 64)     256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 6, 6, 64)     0           max_pooling2d_7[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 6, 6, 128)    8768        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 6, 6, 128)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 6, 6, 128)    17536       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 3, 3, 128)    8192        add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 128)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 3, 3, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 3, 3, 128)    0           max_pooling2d_8[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 3, 3, 7)      8071        add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 7)            0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# Epoch 1/110
# 898/897 [==============================] - 268s 298ms/step - loss: 1.7886 - acc: 0.3204 - val_loss: 1.6734 - val_acc: 0.3643
#
# Epoch 00001: val_loss improved from inf to 1.67344, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.01-0.36.hdf5
# Epoch 2/110
# 898/897 [==============================] - 258s 287ms/step - loss: 1.5387 - acc: 0.4212 - val_loss: 1.8508 - val_acc: 0.3600
#
# Epoch 00002: val_loss did not improve from 1.67344
# Epoch 3/110
# 898/897 [==============================] - 267s 297ms/step - loss: 1.4166 - acc: 0.4646 - val_loss: 1.3733 - val_acc: 0.4694
#
# Epoch 00003: val_loss improved from 1.67344 to 1.37331, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.03-0.47.hdf5
# Epoch 4/110
# 898/897 [==============================] - 253s 282ms/step - loss: 1.3415 - acc: 0.4961 - val_loss: 1.3490 - val_acc: 0.4985
#
# Epoch 00004: val_loss improved from 1.37331 to 1.34897, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.04-0.50.hdf5
# Epoch 5/110
# 898/897 [==============================] - 249s 277ms/step - loss: 1.2927 - acc: 0.5145 - val_loss: 1.5587 - val_acc: 0.4483
#
# Epoch 00005: val_loss did not improve from 1.34897
# Epoch 6/110
# 898/897 [==============================] - 244s 272ms/step - loss: 1.2647 - acc: 0.5259 - val_loss: 1.3118 - val_acc: 0.5106
#
# Epoch 00006: val_loss improved from 1.34897 to 1.31179, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.06-0.51.hdf5
# Epoch 7/110
# 898/897 [==============================] - 240s 268ms/step - loss: 1.2367 - acc: 0.5385 - val_loss: 1.3308 - val_acc: 0.4960
#
# Epoch 00007: val_loss did not improve from 1.31179
# Epoch 8/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.2093 - acc: 0.5469 - val_loss: 1.1973 - val_acc: 0.5595
#
# Epoch 00008: val_loss improved from 1.31179 to 1.19733, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.08-0.56.hdf5
# Epoch 9/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.1882 - acc: 0.5536 - val_loss: 1.2522 - val_acc: 0.5411
#
# Epoch 00009: val_loss did not improve from 1.19733
# Epoch 10/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.1751 - acc: 0.5610 - val_loss: 1.2303 - val_acc: 0.5542
#
# Epoch 00010: val_loss did not improve from 1.19733
# Epoch 11/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.1569 - acc: 0.5689 - val_loss: 1.1388 - val_acc: 0.5678
#
# Epoch 00011: val_loss improved from 1.19733 to 1.13882, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.11-0.57.hdf5
# Epoch 12/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.1437 - acc: 0.5721 - val_loss: 1.1568 - val_acc: 0.5613
#
# Epoch 00012: val_loss did not improve from 1.13882
# Epoch 13/110
# 898/897 [==============================] - 238s 265ms/step - loss: 1.1309 - acc: 0.5759 - val_loss: 1.1975 - val_acc: 0.5524
#
# Epoch 00013: val_loss did not improve from 1.13882
# Epoch 14/110
# 898/897 [==============================] - 237s 263ms/step - loss: 1.1222 - acc: 0.5793 - val_loss: 1.1522 - val_acc: 0.5607
#
# Epoch 00014: val_loss did not improve from 1.13882
# Epoch 15/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.1141 - acc: 0.5836 - val_loss: 1.1180 - val_acc: 0.5755
#
# Epoch 00015: val_loss improved from 1.13882 to 1.11801, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.15-0.58.hdf5
# Epoch 16/110
# 898/897 [==============================] - 245s 272ms/step - loss: 1.0981 - acc: 0.5905 - val_loss: 1.2377 - val_acc: 0.5425
#
# Epoch 00016: val_loss did not improve from 1.11801
# Epoch 17/110
# 898/897 [==============================] - 254s 283ms/step - loss: 1.0871 - acc: 0.5948 - val_loss: 1.1116 - val_acc: 0.5843
#
# Epoch 00017: val_loss improved from 1.11801 to 1.11162, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.17-0.58.hdf5
# Epoch 18/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0845 - acc: 0.5954 - val_loss: 1.1905 - val_acc: 0.5412
#
# Epoch 00018: val_loss did not improve from 1.11162
# Epoch 19/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0721 - acc: 0.6018 - val_loss: 1.1018 - val_acc: 0.5911
#
# Epoch 00019: val_loss improved from 1.11162 to 1.10180, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.19-0.59.hdf5
# Epoch 20/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0698 - acc: 0.6011 - val_loss: 1.1010 - val_acc: 0.5952
#
# Epoch 00020: val_loss improved from 1.10180 to 1.10098, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.20-0.60.hdf5
# Epoch 21/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0638 - acc: 0.6071 - val_loss: 1.0984 - val_acc: 0.5871
#
# Epoch 00021: val_loss improved from 1.10098 to 1.09841, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.21-0.59.hdf5
# Epoch 22/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0575 - acc: 0.6054 - val_loss: 1.1298 - val_acc: 0.5790
#
# Epoch 00022: val_loss did not improve from 1.09841
# Epoch 23/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0581 - acc: 0.6076 - val_loss: 1.1383 - val_acc: 0.5868
#
# Epoch 00023: val_loss did not improve from 1.09841
# Epoch 24/110
# 898/897 [==============================] - 240s 267ms/step - loss: 1.0542 - acc: 0.6077 - val_loss: 1.1445 - val_acc: 0.5850
#
# Epoch 00024: val_loss did not improve from 1.09841
# Epoch 25/110
# 898/897 [==============================] - 262s 291ms/step - loss: 1.0393 - acc: 0.6167 - val_loss: 1.1786 - val_acc: 0.5726
#
# Epoch 00025: val_loss did not improve from 1.09841
# Epoch 26/110
# 898/897 [==============================] - 248s 276ms/step - loss: 1.0391 - acc: 0.6156 - val_loss: 1.0748 - val_acc: 0.5978
#
# Epoch 00026: val_loss improved from 1.09841 to 1.07480, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.26-0.60.hdf5
# Epoch 27/110
# 898/897 [==============================] - 241s 269ms/step - loss: 1.0297 - acc: 0.6195 - val_loss: 1.1426 - val_acc: 0.5706
#
# Epoch 00027: val_loss did not improve from 1.07480
# Epoch 28/110
# 898/897 [==============================] - 239s 267ms/step - loss: 1.0311 - acc: 0.6166 - val_loss: 1.1075 - val_acc: 0.5914
#
# Epoch 00028: val_loss did not improve from 1.07480
# Epoch 29/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0198 - acc: 0.6202 - val_loss: 1.0906 - val_acc: 0.6000
#
# Epoch 00029: val_loss did not improve from 1.07480
# Epoch 30/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0179 - acc: 0.6197 - val_loss: 1.0836 - val_acc: 0.5971
#
# Epoch 00030: val_loss did not improve from 1.07480
# Epoch 31/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0202 - acc: 0.6212 - val_loss: 1.0468 - val_acc: 0.6119
#
# Epoch 00031: val_loss improved from 1.07480 to 1.04678, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.31-0.61.hdf5
# Epoch 32/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0117 - acc: 0.6239 - val_loss: 1.0768 - val_acc: 0.5954
#
# Epoch 00032: val_loss did not improve from 1.04678
# Epoch 33/110
# 898/897 [==============================] - 237s 264ms/step - loss: 1.0109 - acc: 0.6240 - val_loss: 1.0419 - val_acc: 0.6071
#
# Epoch 00033: val_loss improved from 1.04678 to 1.04193, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.33-0.61.hdf5
# Epoch 34/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9980 - acc: 0.6303 - val_loss: 1.1157 - val_acc: 0.5954
#
# Epoch 00034: val_loss did not improve from 1.04193
# Epoch 35/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9991 - acc: 0.6299 - val_loss: 1.0475 - val_acc: 0.6126
#
# Epoch 00035: val_loss did not improve from 1.04193
# Epoch 36/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9949 - acc: 0.6276 - val_loss: 1.0483 - val_acc: 0.6116
#
# Epoch 00036: val_loss did not improve from 1.04193
# Epoch 37/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9982 - acc: 0.6285 - val_loss: 1.0588 - val_acc: 0.6069
#
# Epoch 00037: val_loss did not improve from 1.04193
# Epoch 38/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9898 - acc: 0.6340 - val_loss: 1.1761 - val_acc: 0.5691
#
# Epoch 00038: val_loss did not improve from 1.04193
# Epoch 39/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9894 - acc: 0.6302 - val_loss: 1.0779 - val_acc: 0.6095
#
# Epoch 00039: val_loss did not improve from 1.04193
# Epoch 40/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9857 - acc: 0.6359 - val_loss: 1.1267 - val_acc: 0.6028
#
# Epoch 00040: val_loss did not improve from 1.04193
# Epoch 41/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9819 - acc: 0.6378 - val_loss: 1.0367 - val_acc: 0.6138
#
# Epoch 00041: val_loss improved from 1.04193 to 1.03669, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.41-0.61.hdf5
# Epoch 42/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9709 - acc: 0.6369 - val_loss: 1.0584 - val_acc: 0.6142
#
# Epoch 00042: val_loss did not improve from 1.03669
# Epoch 43/110
# 898/897 [==============================] - 238s 265ms/step - loss: 0.9733 - acc: 0.6386 - val_loss: 1.0666 - val_acc: 0.6030
#
# Epoch 00043: val_loss did not improve from 1.03669
# Epoch 44/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9721 - acc: 0.6404 - val_loss: 1.0344 - val_acc: 0.6206
#
# Epoch 00044: val_loss improved from 1.03669 to 1.03435, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.44-0.62.hdf5
# Epoch 45/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9703 - acc: 0.6425 - val_loss: 1.0682 - val_acc: 0.6073
#
# Epoch 00045: val_loss did not improve from 1.03435
# Epoch 46/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9656 - acc: 0.6416 - val_loss: 1.0718 - val_acc: 0.6049
#
# Epoch 00046: val_loss did not improve from 1.03435
# Epoch 47/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9628 - acc: 0.6434 - val_loss: 1.0375 - val_acc: 0.6222
#
# Epoch 00047: val_loss did not improve from 1.03435
# Epoch 48/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9620 - acc: 0.6411 - val_loss: 1.0400 - val_acc: 0.6131
#
# Epoch 00048: val_loss did not improve from 1.03435
# Epoch 49/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9556 - acc: 0.6450 - val_loss: 1.0153 - val_acc: 0.6261
#
# Epoch 00049: val_loss improved from 1.03435 to 1.01531, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.49-0.63.hdf5
# Epoch 50/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9530 - acc: 0.6480 - val_loss: 1.0460 - val_acc: 0.6186
#
# Epoch 00050: val_loss did not improve from 1.01531
# Epoch 51/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9562 - acc: 0.6456 - val_loss: 1.0607 - val_acc: 0.6176
#
# Epoch 00051: val_loss did not improve from 1.01531
# Epoch 52/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9504 - acc: 0.6495 - val_loss: 1.0974 - val_acc: 0.6049
#
# Epoch 00052: val_loss did not improve from 1.01531
# Epoch 53/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9485 - acc: 0.6475 - val_loss: 1.0517 - val_acc: 0.6148
#
# Epoch 00053: val_loss did not improve from 1.01531
# Epoch 54/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9466 - acc: 0.6505 - val_loss: 1.0503 - val_acc: 0.6195
#
# Epoch 00054: val_loss did not improve from 1.01531
# Epoch 55/110
# 898/897 [==============================] - 244s 272ms/step - loss: 0.9459 - acc: 0.6501 - val_loss: 1.0908 - val_acc: 0.5992
#
# Epoch 00055: val_loss did not improve from 1.01531
# Epoch 56/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9482 - acc: 0.6480 - val_loss: 1.0362 - val_acc: 0.6211
#
# Epoch 00056: val_loss did not improve from 1.01531
# Epoch 57/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9449 - acc: 0.6509 - val_loss: 1.0138 - val_acc: 0.6343
#
# Epoch 00057: val_loss improved from 1.01531 to 1.01380, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.57-0.63.hdf5
# Epoch 58/110
# 898/897 [==============================] - 239s 266ms/step - loss: 0.9351 - acc: 0.6539 - val_loss: 1.0578 - val_acc: 0.6094
#
# Epoch 00058: val_loss did not improve from 1.01380
# Epoch 59/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9451 - acc: 0.6464 - val_loss: 1.0638 - val_acc: 0.6077
#
# Epoch 00059: val_loss did not improve from 1.01380
# Epoch 60/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9355 - acc: 0.6523 - val_loss: 1.0602 - val_acc: 0.6170
#
# Epoch 00060: val_loss did not improve from 1.01380
# Epoch 61/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9336 - acc: 0.6528 - val_loss: 1.0203 - val_acc: 0.6305
#
# Epoch 00061: val_loss did not improve from 1.01380
# Epoch 62/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9385 - acc: 0.6531 - val_loss: 1.0416 - val_acc: 0.6293
#
# Epoch 00062: val_loss did not improve from 1.01380
# Epoch 63/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9315 - acc: 0.6538 - val_loss: 1.0351 - val_acc: 0.6204
#
# Epoch 00063: val_loss did not improve from 1.01380
# Epoch 64/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9302 - acc: 0.6568 - val_loss: 1.0074 - val_acc: 0.6271
#
# Epoch 00064: val_loss improved from 1.01380 to 1.00741, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.64-0.63.hdf5
# Epoch 65/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9233 - acc: 0.6589 - val_loss: 1.1399 - val_acc: 0.6035
#
# Epoch 00065: val_loss did not improve from 1.00741
# Epoch 66/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9235 - acc: 0.6611 - val_loss: 1.0678 - val_acc: 0.6222
#
# Epoch 00066: val_loss did not improve from 1.00741
# Epoch 67/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9177 - acc: 0.6595 - val_loss: 1.0338 - val_acc: 0.6254
#
# Epoch 00067: val_loss did not improve from 1.00741
# Epoch 68/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9178 - acc: 0.6597 - val_loss: 1.0900 - val_acc: 0.6151
#
# Epoch 00068: val_loss did not improve from 1.00741
# Epoch 69/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9185 - acc: 0.6599 - val_loss: 1.0280 - val_acc: 0.6294
#
# Epoch 00069: val_loss did not improve from 1.00741
# Epoch 70/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9216 - acc: 0.6576 - val_loss: 1.0034 - val_acc: 0.6353
#
# Epoch 00070: val_loss improved from 1.00741 to 1.00337, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.70-0.64.hdf5
# Epoch 71/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9175 - acc: 0.6594 - val_loss: 1.0189 - val_acc: 0.6229
#
# Epoch 00071: val_loss did not improve from 1.00337
# Epoch 72/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9210 - acc: 0.6577 - val_loss: 1.0251 - val_acc: 0.6268
#
# Epoch 00072: val_loss did not improve from 1.00337
# Epoch 73/110
# 898/897 [==============================] - 239s 266ms/step - loss: 0.9172 - acc: 0.6583 - val_loss: 1.0167 - val_acc: 0.6265
#
# Epoch 00073: val_loss did not improve from 1.00337
# Epoch 74/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9110 - acc: 0.6644 - val_loss: 1.0183 - val_acc: 0.6304
#
# Epoch 00074: val_loss did not improve from 1.00337
# Epoch 75/110
# 898/897 [==============================] - 244s 271ms/step - loss: 0.9140 - acc: 0.6628 - val_loss: 1.0266 - val_acc: 0.6254
#
# Epoch 00075: val_loss did not improve from 1.00337
# Epoch 76/110
# 898/897 [==============================] - 246s 274ms/step - loss: 0.9113 - acc: 0.6618 - val_loss: 1.0346 - val_acc: 0.6252
#
# Epoch 00076: val_loss did not improve from 1.00337
# Epoch 77/110
# 898/897 [==============================] - 241s 268ms/step - loss: 0.9092 - acc: 0.6617 - val_loss: 1.0091 - val_acc: 0.6279
#
# Epoch 00077: val_loss did not improve from 1.00337
# Epoch 78/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9035 - acc: 0.6651 - val_loss: 1.0428 - val_acc: 0.6174
#
# Epoch 00078: val_loss did not improve from 1.00337
# Epoch 79/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9024 - acc: 0.6665 - val_loss: 1.1352 - val_acc: 0.5887
#
# Epoch 00079: val_loss did not improve from 1.00337
# Epoch 80/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9029 - acc: 0.6674 - val_loss: 1.0501 - val_acc: 0.6220
#
# Epoch 00080: val_loss did not improve from 1.00337
# Epoch 81/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.8988 - acc: 0.6694 - val_loss: 1.0075 - val_acc: 0.6365
#
# Epoch 00081: val_loss did not improve from 1.00337
# Epoch 82/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.9008 - acc: 0.6666 - val_loss: 0.9926 - val_acc: 0.6361
#
# Epoch 00082: val_loss improved from 1.00337 to 0.99257, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.82-0.64.hdf5
# Epoch 83/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.8999 - acc: 0.6687 - val_loss: 1.0482 - val_acc: 0.6282
#
# Epoch 00083: val_loss did not improve from 0.99257
# Epoch 84/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.9004 - acc: 0.6672 - val_loss: 1.0074 - val_acc: 0.6296
#
# Epoch 00084: val_loss did not improve from 0.99257
# Epoch 85/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8994 - acc: 0.6667 - val_loss: 1.0583 - val_acc: 0.6259
#
# Epoch 00085: val_loss did not improve from 0.99257
# Epoch 86/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8968 - acc: 0.6682 - val_loss: 1.1024 - val_acc: 0.6102
#
# Epoch 00086: val_loss did not improve from 0.99257
# Epoch 87/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.8975 - acc: 0.6684 - val_loss: 1.0223 - val_acc: 0.6287
#
# Epoch 00087: val_loss did not improve from 0.99257
# Epoch 88/110
# 898/897 [==============================] - 239s 266ms/step - loss: 0.8913 - acc: 0.6708 - val_loss: 1.0324 - val_acc: 0.6290
#
# Epoch 00088: val_loss did not improve from 0.99257
# Epoch 89/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8876 - acc: 0.6719 - val_loss: 1.0086 - val_acc: 0.6395
#
# Epoch 00089: val_loss did not improve from 0.99257
# Epoch 90/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.8896 - acc: 0.6715 - val_loss: 0.9934 - val_acc: 0.6395
#
# Epoch 00090: val_loss did not improve from 0.99257
# Epoch 91/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8897 - acc: 0.6744 - val_loss: 1.0429 - val_acc: 0.6254
#
# Epoch 00091: val_loss did not improve from 0.99257
# Epoch 92/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8868 - acc: 0.6711 - val_loss: 1.0632 - val_acc: 0.6201
#
# Epoch 00092: val_loss did not improve from 0.99257
# Epoch 93/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.8894 - acc: 0.6708 - val_loss: 1.0498 - val_acc: 0.6326
#
# Epoch 00093: val_loss did not improve from 0.99257
# Epoch 94/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8867 - acc: 0.6720 - val_loss: 1.0137 - val_acc: 0.6347
#
# Epoch 00094: val_loss did not improve from 0.99257
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 95/110
# 898/897 [==============================] - 237s 263ms/step - loss: 0.8446 - acc: 0.6916 - val_loss: 0.9847 - val_acc: 0.6484
#
# Epoch 00095: val_loss improved from 0.99257 to 0.98471, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.95-0.65.hdf5
# Epoch 96/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8366 - acc: 0.6941 - val_loss: 0.9726 - val_acc: 0.6524
#
# Epoch 00096: val_loss improved from 0.98471 to 0.97263, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.96-0.65.hdf5
# Epoch 97/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8215 - acc: 0.6986 - val_loss: 0.9679 - val_acc: 0.6527
#
# Epoch 00097: val_loss improved from 0.97263 to 0.96794, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.97-0.65.hdf5
# Epoch 98/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.8230 - acc: 0.6984 - val_loss: 0.9706 - val_acc: 0.6484
#
# Epoch 00098: val_loss did not improve from 0.96794
# Epoch 99/110
# 898/897 [==============================] - 243s 271ms/step - loss: 0.8209 - acc: 0.6968 - val_loss: 0.9684 - val_acc: 0.6488
#
# Epoch 00099: val_loss did not improve from 0.96794
# Epoch 100/110
# 898/897 [==============================] - 255s 284ms/step - loss: 0.8159 - acc: 0.7006 - val_loss: 0.9654 - val_acc: 0.6491
#
# Epoch 00100: val_loss improved from 0.96794 to 0.96545, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.100-0.65.hdf5
# Epoch 101/110
# 898/897 [==============================] - 246s 274ms/step - loss: 0.8161 - acc: 0.6999 - val_loss: 0.9630 - val_acc: 0.6539
#
# Epoch 00101: val_loss improved from 0.96545 to 0.96304, saving model to /home/jogel/Documents/emoRec/FaceEmotion_ID-master/models/_mini_XCEPTION.101-0.65.hdf5
# Epoch 102/110
# 898/897 [==============================] - 247s 275ms/step - loss: 0.8112 - acc: 0.7014 - val_loss: 0.9664 - val_acc: 0.6512
#
# Epoch 00102: val_loss did not improve from 0.96304
# Epoch 103/110
# 898/897 [==============================] - 247s 275ms/step - loss: 0.8039 - acc: 0.7009 - val_loss: 0.9684 - val_acc: 0.6509
#
# Epoch 00103: val_loss did not improve from 0.96304
# Epoch 104/110
# 898/897 [==============================] - 262s 292ms/step - loss: 0.8074 - acc: 0.6997 - val_loss: 0.9740 - val_acc: 0.6486
#
# Epoch 00104: val_loss did not improve from 0.96304
# Epoch 105/110
# 898/897 [==============================] - 263s 293ms/step - loss: 0.8055 - acc: 0.7035 - val_loss: 0.9700 - val_acc: 0.6521
#
# Epoch 00105: val_loss did not improve from 0.96304
# Epoch 106/110
# 898/897 [==============================] - 257s 286ms/step - loss: 0.8069 - acc: 0.7018 - val_loss: 0.9731 - val_acc: 0.6481
#
# Epoch 00106: val_loss did not improve from 0.96304
# Epoch 107/110
# 898/897 [==============================] - 259s 288ms/step - loss: 0.7981 - acc: 0.7028 - val_loss: 0.9709 - val_acc: 0.6499
#
# Epoch 00107: val_loss did not improve from 0.96304
# Epoch 108/110
# 898/897 [==============================] - 259s 288ms/step - loss: 0.8055 - acc: 0.7034 - val_loss: 0.9736 - val_acc: 0.6474
#
# Epoch 00108: val_loss did not improve from 0.96304
# Epoch 109/110
# 898/897 [==============================] - 263s 292ms/step - loss: 0.8071 - acc: 0.7016 - val_loss: 0.9726 - val_acc: 0.6495
#
# Epoch 00109: val_loss did not improve from 0.96304
# Epoch 110/110
# 898/897 [==============================] - 264s 294ms/step - loss: 0.8043 - acc: 0.6987 - val_loss: 0.9736 - val_acc: 0.6505
#
# Epoch 00110: val_loss did not improve from 0.96304

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("Agg")
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = num_epochs
plt.plot(np.arange(0, N), model.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), model.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), model.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), model.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy fer2013 dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")
plt.savefig("EmoTrainFer2013.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ae8875a49f3f> in <module>
#       6 plt.figure()
#       7 N = num_epochs
# ----> 8 plt.plot(np.arange(0, N), model.history["loss"], label="train_loss")
#       9 plt.plot(np.arange(0, N), model.history["val_loss"], label="val_loss")
#      10 plt.plot(np.arange(0, N), model.history["acc"], label="train_acc")
#
# TypeError: 'History' object is not subscriptable

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print("Predicting emotion's names on the test set")
y_pred = model.predict(xtest)
#emotions_ = [0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral]

print("Confusion Matrix")
print(confusion_matrix(ytest, y_pred)) #,labels=range(num_classes)))
print("")
print("Classification Report")
print(classification_report(ytest, y_pred, target_names=emotions_))
# Out:
# Predicting emotion's names on the test set
# Confusion Matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2e9e139dce50> in <module>
#       7
#       8 print("Confusion Matrix")
# ----> 9 print(confusion_matrix(ytest, y_pred)) #,labels=range(num_classes)))
#      10 print("")
#      11 print("Classification Report")
#
# ~/caffe_gpu/lib/python3.6/site-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~/caffe_gpu/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %%
scores = model.evaluate(xtrain, ytrain, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# acc: 72.60%

# %%
from keras.models import model_from_json
# serialize model to JSON
model_json = model.to_json()
with open("EmoClassModel.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("EmoClassWeights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load json and create model
json_file = open('EmoClassModel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("EmoClassWeights.h5")
print("Loaded model from disk")
print('Model Summary:')
print(loaded_model.summary())
# Out:
# Loaded model from disk
# Model Summary:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 46, 46, 8)    72          input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 46, 46, 8)    32          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 46, 46, 8)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 44, 44, 8)    576         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 44, 44, 8)    32          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 44, 44, 8)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 44, 44, 16)   200         activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 44, 44, 16)   64          separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 44, 44, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 44, 44, 16)   400         activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 44, 44, 16)   64          separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 22, 22, 16)   128         activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 22, 22, 16)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 22, 22, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 22, 22, 16)   0           max_pooling2d_5[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 22, 22, 32)   656         add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 22, 22, 32)   128         separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 22, 22, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 22, 22, 32)   1312        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 22, 22, 32)   128         separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 11, 11, 32)   512         add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 11, 11, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 11, 11, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 11, 11, 32)   0           max_pooling2d_6[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 11, 11, 64)   2336        add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 11, 11, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 11, 11, 64)   4672        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 6, 6, 64)     2048        add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 64)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 64)     256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 6, 6, 64)     0           max_pooling2d_7[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 6, 6, 128)    8768        add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 6, 6, 128)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 6, 6, 128)    17536       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 3, 3, 128)    8192        add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 128)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 3, 3, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 3, 3, 128)    0           max_pooling2d_8[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 3, 3, 7)      8071        add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 7)            0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# None

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(xtest, ytest, verbose=1)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# 7178/7178 [==============================] - 16s 2ms/step
# acc: 65.05%
